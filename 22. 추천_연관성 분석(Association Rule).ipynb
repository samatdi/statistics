# %%
#pip install mlxtend

# %%
import pandas as pd 
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv("실기 Python 실습파일 (2)/association_rules_mart.csv")
df.head(2)
# Out:
#          Date         ID          Item
# 0  2014-01-01  1249in804  citrus fruit
# 1  2014-01-01  1249in804        coffee

# %%
df["purchase"]=True

# %%
df_pivot = df.pivot_table(index = "ID", columns = "Item",
                          values = 'purchase', aggfunc = max,
                          fill_value = False)
df_pivot.head(2)
# Out:
# Item      Instant food products UHT-milk abrasive cleaner artif. sweetener  \
# ID
# 1000ol738                 False    False            False            False
# 1001sf480                 False    False            False            False
#
# Item      baby cosmetics   bags baking powder bathroom cleaner   beef berries  \
# ID
# 1000ol738          False  False         False            False  False   False
# 1001sf480          False  False         False            False   True   False
#
# Item       ... turkey vinegar waffles whipped/sour cream whisky white bread  \
# ID         ...
# 1000ol738  ...  False   False   False              False  False       False
# 1001sf480  ...  False   False   False               True  False        True
#
# Item      white wine whole milk yogurt zwieback
# ID
# 1000ol738      False       True   True    False
# 1001sf480      False       True  False    False
#
# [2 rows x 167 columns]

# %%
item_freq = apriori(df_pivot, min_support = 0.005, use_colnames =True)
item_freq.head()
# Out:
#     support                 itemsets
# 0  0.015393  (Instant food products)
# 1  0.078502               (UHT-milk)
# 2  0.005644       (abrasive cleaner)
# 3   0.00744       (artif. sweetener)
# 4  0.031042          (baking powder)

# %%
df_rules = association_rules(item_freq, metric ="lift",
                             min_threshold =1.5)
df_rules.head()
# Out:
#                antecedents              consequents  antecedent support  \
# 0        (root vegetables)  (Instant food products)            0.230631
# 1  (Instant food products)        (root vegetables)            0.015393
# 2  (Instant food products)                   (soda)            0.015393
# 3                   (soda)  (Instant food products)            0.313494
# 4               (UHT-milk)                  (candy)            0.078502
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.015393  0.006927    0.030033  1.951168  0.003377    1.015094
# 1            0.230631  0.006927    0.450000  1.951168  0.003377    1.398853
# 2            0.313494  0.007953    0.516667  1.648091  0.003127    1.420357
# 3            0.015393  0.007953    0.025368  1.648091  0.003127    1.010235
# 4            0.053874  0.007440    0.094771  1.759135  0.003211    1.045179

# %% [markdown]
# # 문제

# %% [markdown]
# Q1.

# %%
df = pd.read_csv("실기 Python 실습파일 (2)/association_rules_mart.csv")
df.head(2)
# Out:
#          Date         ID          Item
# 0  2014-01-01  1249in804  citrus fruit
# 1  2014-01-01  1249in804        coffee

# %%
len(df)
# Out:
# 40000

# %%
df = df.iloc[:,1:].drop_duplicates()
len(df)
# Out:
# 34766

# %%
df["purchase"]=True
df_pivot = df.pivot_table(index = "ID", columns = "Item",
                          values = 'purchase', aggfunc = max,
                          fill_value = False)
df_pivot.head(2)
# Out:
# Item      Instant food products UHT-milk abrasive cleaner artif. sweetener  \
# ID
# 1000ol738                 False    False            False            False
# 1001sf480                 False    False            False            False
#
# Item      baby cosmetics   bags baking powder bathroom cleaner   beef berries  \
# ID
# 1000ol738          False  False         False            False  False   False
# 1001sf480          False  False         False            False   True   False
#
# Item       ... turkey vinegar waffles whipped/sour cream whisky white bread  \
# ID         ...
# 1000ol738  ...  False   False   False              False  False       False
# 1001sf480  ...  False   False   False               True  False        True
#
# Item      white wine whole milk yogurt zwieback
# ID
# 1000ol738      False       True   True    False
# 1001sf480      False       True  False    False
#
# [2 rows x 167 columns]

# %%
item_sets = apriori(df = df_pivot, 
                    min_support = 0.005, use_colnames =True)
item_freq.head(2)
# Out:
#     support                 itemsets
# 0  0.015393  (Instant food products)
# 1  0.078502               (UHT-milk)

# %%
rules = association_rules(item_sets, 
                          metric ="confidence",
                          min_threshold =0.005)
rules.head(2)
# Out:
#                antecedents              consequents  antecedent support  \
# 0             (rolls/buns)  (Instant food products)            0.349666
# 1  (Instant food products)             (rolls/buns)            0.015393
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.015393  0.005387    0.015407  1.000954  0.000005    1.000015
# 1            0.349666  0.005387    0.350000  1.000954  0.000005    1.000513

# %%
rules_sub = rules.loc[rules["support"]>0.1,]
rules_sub = rules_sub.sort_values("lift", ascending = False)
rules_sub.head(2)
# Out:
#        antecedents   consequents  antecedent support  consequent support  \
# 4193  (whole milk)      (yogurt)            0.458184            0.282966
# 4192      (yogurt)  (whole milk)            0.282966            0.458184
#
#       support  confidence     lift  leverage  conviction
# 4193  0.15059    0.328667  1.16151   0.02094    1.068076
# 4192  0.15059    0.532185  1.16151   0.02094    1.158185

# %%
len(rules_sub)
# Out:
# 26

# %% [markdown]
# Q2

# %%
df = pd.read_csv("실기 Python 실습파일 (2)/association_rules_mart.csv")
df = df.iloc[:,1:].drop_duplicates()
len(df)
# Out:
# 34766

# %%
df["purchase"]=True
df_pivot = pd.pivot_table(data = df, 
                          index = "ID", columns = "Item",
                          values = 'purchase', aggfunc = max,
                          fill_value = False)
df_pivot.head(2)
# Out:
# Item      Instant food products UHT-milk abrasive cleaner artif. sweetener  \
# ID
# 1000ol738                 False    False            False            False
# 1001sf480                 False    False            False            False
#
# Item      baby cosmetics   bags baking powder bathroom cleaner   beef berries  \
# ID
# 1000ol738          False  False         False            False  False   False
# 1001sf480          False  False         False            False   True   False
#
# Item       ... turkey vinegar waffles whipped/sour cream whisky white bread  \
# ID         ...
# 1000ol738  ...  False   False   False              False  False       False
# 1001sf480  ...  False   False   False               True  False        True
#
# Item      white wine whole milk yogurt zwieback
# ID
# 1000ol738      False       True   True    False
# 1001sf480      False       True  False    False
#
# [2 rows x 167 columns]

# %%
item_sets = apriori(df = df_pivot, 
                    min_support = 0.005, 
                    use_colnames =True,
                    max_len = 3)
item_freq.head(2)
# Out:
#     support                 itemsets
# 0  0.015393  (Instant food products)
# 1  0.078502               (UHT-milk)

# %%
item_sets.tail(2)
# Out:
#        support                           itemsets
# 7213  0.016419  (yogurt, whole milk, white bread)
# 7214  0.009749   (yogurt, white wine, whole milk)

# %%
rules = association_rules(item_sets, 
                          metric ="confidence",
                          min_threshold =0.005)
rules.head(2)
# Out:
#                antecedents              consequents  antecedent support  \
# 0             (rolls/buns)  (Instant food products)            0.349666
# 1  (Instant food products)             (rolls/buns)            0.015393
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.015393  0.005387    0.015407  1.000954  0.000005    1.000015
# 1            0.349666  0.005387    0.350000  1.000954  0.000005    1.000513

# %%
rules_sub = rules.loc[rules["support"]>0.01,]
rules_sub = rules_sub.sort_values("lift", ascending = False)
rules_sub.head(2)
# Out:
#                        antecedents                  consequents  \
# 22840  (domestic eggs, whole milk)                       (meat)
# 22845                       (meat)  (domestic eggs, whole milk)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 22840            0.070292            0.063622  0.010262    0.145985  2.294561
# 22845            0.063622            0.070292  0.010262    0.161290  2.294561
#
#        leverage  conviction
# 22840  0.005789    1.096442
# 22845  0.005789    1.108497

# %% [markdown]
# Q3.

# %%
df = pd.read_csv("실기 Python 실습파일 (2)/association_rules_mart.csv")
df.head(2)
# Out:
#          Date         ID          Item
# 0  2014-01-01  1249in804  citrus fruit
# 1  2014-01-01  1249in804        coffee

# %%
df_item_cnt = df["Item"].value_counts().reset_index()
df_item_cnt = df_item_cnt.sort_values("Item", ascending = False)
df_item_cnt.head()
# Out:
#               index  Item
# 0        whole milk  2570
# 1  other vegetables  1951
# 2        rolls/buns  1778
# 3              soda  1558
# 4            yogurt  1373

# %%
df_item_cnt = df_item_cnt.iloc[:30,]
df_item_cnt.head(2)
# Out:
#               index  Item
# 0        whole milk  2570
# 1  other vegetables  1951

# %%
df_sub = df.loc[df["Item"].isin(df_item_cnt["index"]),]
df_sub.head()
# Out:
#          Date         ID              Item
# 0  2014-01-01  1249in804      citrus fruit
# 1  2014-01-01  1249in804            coffee
# 2  2014-01-01  1381ht273              curd
# 3  2014-01-01  1381ht273              soda
# 4  2014-01-01  1440kn258  other vegetables

# %%
len(df_sub)
# Out:
# 25979

# %%
df_sub["purchase"]=True
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_25724/961166092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub["purchase"]=True

# %%
df_pivot = pd.pivot_table(data = df_sub, 
                          index = "ID", columns = "Item",
                          values = "purchase", aggfunc = max,
                          fill_value = False)
df_pivot.head(2)
# Out:
# Item        beef bottled beer bottled water brown bread butter canned beer  \
# ID
# 1000ol738  False        False         False       False  False        True
# 1001sf480   True        False         False       False  False       False
#
# Item      chicken citrus fruit coffee   curd  ... rolls/buns root vegetables  \
# ID                                            ...
# 1000ol738   False        False  False  False  ...      False           False
# 1001sf480   False        False  False   True  ...       True           False
#
# Item      sausage shopping bags  soda tropical fruit whipped/sour cream  \
# ID
# 1000ol738    True         False  True          False              False
# 1001sf480    True         False  True          False               True
#
# Item      white bread whole milk yogurt
# ID
# 1000ol738       False       True   True
# 1001sf480        True       True  False
#
# [2 rows x 30 columns]

# %%
item_sets = apriori(df = df_pivot, 
                    min_support = 0.005, 
                    use_colnames =True)
                    
item_freq.head(2)
# Out:
#     support                 itemsets
# 0  0.015393  (Instant food products)
# 1  0.078502               (UHT-milk)

# %%
rules = association_rules(item_sets, 
                          metric ="confidence",
                          min_threshold =0.005)
rules.head(2)
# Out:
#       antecedents     consequents  antecedent support  consequent support  \
# 0          (beef)  (bottled beer)            0.120538            0.160114
# 1  (bottled beer)          (beef)            0.160114            0.120538
#
#     support  confidence      lift  leverage  conviction
# 0  0.020952    0.173820  1.085601  0.001652    1.016590
# 1  0.020952    0.130856  1.085601  0.001652    1.011872

# %%
rules_sub = rules.loc[rules["support"]>0.03,]
rules_sub = rules_sub.sort_values("lift", ascending = False)
rules_sub.head(2)
# Out:
#                           antecedents                     consequents  \
# 41844  (other vegetables, whole milk)            (yogurt, rolls/buns)
# 41841            (yogurt, rolls/buns)  (other vegetables, whole milk)
#
#        antecedent support  consequent support   support  confidence      lift  \
# 41844            0.192964            0.112261  0.034661    0.179625  1.600067
# 41841            0.112261            0.192964  0.034661    0.308756  1.600067
#
#        leverage  conviction
# 41844  0.012999    1.082114
# 41841  0.012999    1.167512
